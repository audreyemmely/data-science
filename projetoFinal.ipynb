# %% [markdown]
# <a href="https://colab.research.google.com/github/audreyemmely/ciencia-de-dados/blob/main/projetoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
base = pd.read_csv('https://raw.githubusercontent.com/audreyemmely/ciencia-de-dados/main/projeto/dados/pessoal-forca-trabalho.csv')

# %%
base.head()
# Out:
#    orgao_superior_codigo_siorg  ... remuneracao_media
# 0                           14  ...          8789.350
# 1                           14  ...          2701.460
# 2                           14  ...          8052.690
# 3                           14  ...          3145.034
# 4                           14  ...          7048.090
#
# [5 rows x 17 columns]

# %%
import numpy as np

# %%
# Remover acentuação dos dados das colunas

def remove_accents(input_str):
    return input_str.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

cols = base.select_dtypes(include=[np.object]).columns

base[cols] = base[cols].apply(remove_accents)

# %%
base.head()
# Out:
#    orgao_superior_codigo_siorg  ... remuneracao_media
# 0                           14  ...          8789.350
# 1                           14  ...          2701.460
# 2                           14  ...          8052.690
# 3                           14  ...          3145.034
# 4                           14  ...          7048.090
#
# [5 rows x 17 columns]
